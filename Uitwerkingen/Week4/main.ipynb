# %% [markdown]
# ## Super plan voor de code
#
# # Kay maakt minesweeper
# # Bas maakt suduko
# # Dennis maakt black jack
#
# # Iedereen volgt de taken die voorgesteld zijn in de huiswerk bestand.
# # Daarnaast moet iedereen elkaars code checken voor bugs en elkaars code interviewen.
