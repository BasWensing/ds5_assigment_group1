# %%
# Bas4

# %%
# Exercise 2.1
# prompt 1: 
# Write me a plan for exercise 2. I am a student using Python to code sudoku. 
# I want a step-by-step implementation plan for a Python 3 Tkinter-based 9x9 Sudoku application.
# Format the entire response in clean Markdown and 
# break down the plan into logical development phases.

# Markdown-file met stappen staat in de map.

# %%
# Folders aanmaken
import os

# Definieer de mappen die aangemaakt moeten worden
folders = ["sudoku_project/sudoku", "sudoku_project/examples", "sudoku_project/data", "sudoku_project/tests"]

# Definieer de bestanden die aangemaakt moeten worden
files = [
    "sudoku_project/README.md",
    "sudoku_project/requirements.txt",
    "sudoku_project/sudoku/__init__.py",
    "sudoku_project/sudoku/board.py",
    "sudoku_project/sudoku/solver.py",
    "sudoku_project/sudoku/file_loader.py",
    "sudoku_project/sudoku/gui.py",
    "sudoku_project/examples/example_cli.py",
    "sudoku_project/examples/example_gui.py",
    "sudoku_project/data/puzzle_01.txt",
    "sudoku_project/data/puzzle_02.json",
    "sudoku_project/tests/__init__.py",
    "sudoku_project/tests/test_board.py",
    "sudoku_project/tests/test_solver.py",
    "sudoku_project/tests/test_file_loader.py",
]

# Mappen aanmaken
for folder in folders:
    os.makedirs(folder, exist_ok=True)

# Lege bestanden aanmaken
for file in files:
    with open(file, "w") as f:
        pass

print("Projectstructuur 'sudoku_project' is succesvol aangemaakt!") # Suduko-map is aangemaakt in de Github-omgeving.
# Out:
# Projectstructuur 'sudoku_project' is succesvol aangemaakt!
