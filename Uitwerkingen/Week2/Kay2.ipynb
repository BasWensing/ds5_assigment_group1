# %%
# Kay2

# %%
# Functies:

# complex(x,y) is als volgt gedefineert:
# c = complex (x,y)
# waarbij c = x + yj



# draw_Mandel(width)
# Dit bepaalt de grootte van de afbeelding, als ik bijv. draw_Mandel(200) invul dan krijg een afbeelding van 200x200, dit zorgt altijd voor een perfect vierkant.

# %%
import numpy as np
c = [] # maakt een lijst aan voor alle c's die we nodig hebben
def complex(x,y): # Definieert de complex functie   
    c.append(x + y*1j) # Rekened de x + y*i uit en voegt deze toe aan een list

# %%
import matplotlib.pyplot as plt
def draw_mandel(width): # Definieert hoe groot de afbeelding moet zijn
    plt.figure(figsize =(width,width)) # Definieert hoe groot de afbeelding moet zijn volgens en past dit toe and de figure
